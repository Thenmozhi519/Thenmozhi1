# %%
import pandas as pd

# Use a raw string (r'...') to prevent backslashes from being interpreted as escape characters
fraud_data = pd.read_csv(r"fraudTest.csv")
fraud_data=pd.read_csv(r"fraudTrain.csv")
fraud_data.head()
pd.options.display.min_rows = None

pd.options.display.max_columns= None
fraud_data.head()
fraud_data.tail()
fraud_data.shape
fraud_data.size
print("number of columns{}".format(fraud_data.shape[0]))
print("no.of rows{}".format(fraud_data.shape[1]))
print("number of columns:{}".format(fraud_data.shape[0]))
print("number of rows:{}".format(fraud_data.shape[0]))
fraud_data.info()
fraud_data.isnull().sum()
from sklearn.preprocessing import StandardScaler
std_scaler=StandardScaler()
std_scaler=StandardScaler()
fraud_data["amt"] = std_scaler.fit_transform(pd.DataFrame(fraud_data["amt"]))
fraud_data.head()
fraud_data = fraud_data.drop(["merchant"],axis=1)
fraud_data = fraud_data.drop(["trans_date_trans_time"],axis=1)
fraud_data.columns
fraud_data.duplicated().any()
fraud_data[fraud_data.duplicated()]
fraud_data.drop_duplicates(keep="first",inplace=True)
fraud_data.duplicated().sub(1)
fraud_data.describe()
fraud_data["amt"].unique()
len(fraud_data["zip"]==0)
len(fraud_data["zip"]==1)
fraud_data["lat"].value_counts()
import seaborn as sns
sns.countplot(x=fraud_data["cc_num"],hue=fraud_data["cc_num"])
feature_data = fraud_data.drop("city", axis=1)
target_variable = fraud_data['city']
import statsmodels.api as sm

target_numeric = target_variable.factorize()[0]
target_constant = sm.add_constant(target_numeric)
for col in feature_data.columns:
    if feature_data[col].dtype == 'object':
        print(f"Converting column '{col}' to numerical labels")
        feature_data[col] = feature_data[col].factorize()[0]

import scipy
from scipy.stats import chi2
chi2.pdf(4747.8,29)
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
import pandas as pd
from sklearn.model_selection import train_test_split

# Use a raw string here as well
test_data = pd.read_csv(r'fraudTest.csv')
feature_data = test_data.drop("city", axis=1)
target_variable = test_data["city"].ravel()
train_features, test_features, train_target, test_target = train_test_split(feature_data, target_variable, test_size=0.3, random_state=22)
len(train_features),len(test_features),len(train_target),len(test_target)
test_data.city
test_data.lat
test_data.amt
test_data.zip
# Out:
# number of columns170849
# no.of rows23
# number of columns:170849
# number of rows:170849
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 170849 entries, 0 to 170848
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   Unnamed: 0             170849 non-null  int64
#  1   trans_date_trans_time  170849 non-null  object
#  2   cc_num                 170849 non-null  int64
#  3   merchant               170849 non-null  object
#  4   category               170849 non-null  object
#  5   amt                    170849 non-null  float64
#  6   first                  170849 non-null  object
#  7   last                   170849 non-null  object
#  8   gender                 170849 non-null  object
#  9   street                 170849 non-null  object
#  10  city                   170849 non-null  object
#  11  state                  170849 non-null  object
# ...
